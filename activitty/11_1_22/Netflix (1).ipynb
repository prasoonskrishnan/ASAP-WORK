# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data = pd.read_csv("C:\\Users\\admin\\Documents\\document\\data science\\netflix.csv')

# %%
data.iloc[344]
# Out:
# show_id                                                      s345
# type                                                        Movie
# title                                                   My Girl 2
# director                                             Howard Zieff
# cast            Anna Chlumsky, Austin O'Brien, Dan Aykroyd, Ja...
# country                                             United States
# date_added                                         August 1, 2021
# release_year                                                 1994
# rating                                                         PG
# duration                                                   99 min
# listed_in              Children & Family Movies, Comedies, Dramas
# description     A teen makes surprising discoveries when she t...
# Name: 344, dtype: object

# %% [markdown]
# ### 1

# %%
data[data['title']=='House of Cards'][['show_id','director']]
# Out:
#      show_id director
# 1059   s1060      NaN

# %% [markdown]
# ### 2

# %%
print(f'Year having highest number of tv shows and movies :{data["release_year"].value_counts().index[0]}')
# Out:
# Year having highest number of tv shows and movies :2018

# %% [markdown]
# ### 3

# %%
a = data['type'].value_counts()
a = pd.DataFrame(a)
a.reset_index(inplace=True)
a
# Out:
#      index  type
# 0    Movie  6131
# 1  TV Show  2676

# %%
sns.catplot(x='index',y='type',data=a,kind='bar');

# %% [markdown]
# ### 4

# %%
data.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...

# %%
d = data[data['release_year']==2000]
d[d['type']=='Movie'][['title','type','release_year']]
# Out:
#                                                   title   type  release_year
# 180                  The Nutty Professor II: The Klumps  Movie          2000
# 350                                       Space Cowboys  Movie          2000
# 359                        The Original Kings of Comedy  Movie          2000
# 566                                    Charlie's Angels  Movie          2000
# 593                                            Snow Day  Movie          2000
# 779                                   Battlefield Earth  Movie          2000
# 952                                The Whole Nine Yards  Movie          2000
# 3472                        Rugrats in Paris: The Movie  Movie          2000
# 4545             Monty Python: Before the Flying Circus  Movie          2000
# 4723                                               Fiza  Movie          2000
# 4956                        Phir Bhi Dil Hai Hindustani  Movie          2000
# ...

# %% [markdown]
# ### 5

# %%
data.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...

# %%
d1 = data[data['country']=='India']
d1[d1['type']=='TV Show'][['country','title','type']]
# Out:
#      country                               title     type
# 4      India                        Kota Factory  TV Show
# 39     India                        Chhota Bheem  TV Show
# 50     India                       Dharmakshetra  TV Show
# 66     India       Raja Rasoi Aur Anya Kahaniyan  TV Show
# 69     India      Stories by Rabindranath Tagore  TV Show
# ...      ...                                 ...      ...
# 8173   India                           Thackeray  TV Show
# 8235   India                         The Calling  TV Show
# 8321   India  The Golden Years with Javed Akhtar  TV Show
# 8349   India              The House That Made Me  TV Show
# 8775   India                     Yeh Meri Family  TV Show
#
# [79 rows x 3 columns]

# %% [markdown]
# ### 6

# %%
data.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...

# %%
data['director'].value_counts().head(10)
# Out:
# Rajiv Chilaka             19
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Suhas Kadav               16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Martin Scorsese           12
# Youssef Chahine           12
# Jay Chapman               12
# Steven Spielberg          11
# Name: director, dtype: int64

# %% [markdown]
# ### 7

# %%
data.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...

# %%
df1 = data[data['listed_in'].apply(lambda x:True if 'Comedies' in x else False)]
df1[(df1['type']=='Movie') | (df1['country']=='United Kingdom')]
# Out:
#      show_id   type                             title  \
# 9        s10  Movie                      The Starling
# 13       s14  Movie  Confessions of an Invisible Girl
# 22       s23  Movie                   Avvai Shanmughi
# 24       s25  Movie                             Jeans
# 26       s27  Movie                    Minsara Kanavu
# ...      ...    ...                               ...
# 8791   s8792  Movie                       Young Adult
# 8793   s8794  Movie              Yours, Mine and Ours
# 8798   s8799  Movie                          Zed Plus
# 8804   s8805  Movie                        Zombieland
# 8805   s8806  Movie                              Zoom
#
#                      director  \
# 9              Theodore Melfi
# 13              Bruno Garotti
# 22             K.S. Ravikumar
# 24                 S. Shankar
# 26                Rajiv Menon
# ...                       ...
# 8791            Jason Reitman
# 8793             Raja Gosnell
# 8798  Chandra Prakash Dwivedi
# ...

# %% [markdown]
# ### 8

# %%
data.head(5)
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df3 = data[data['cast'].apply(lambda x:True if 'Tom Cruise' in x else False)]
print(f"Number of movies, Tom Cruise acted : {df3['cast'].count()}")
# Out:
# Number of movies, Tom Cruise acted : 2

# %% [markdown]
# ### 9

# %%
data.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...

# %%
rate = pd.DataFrame(data['rating'].unique(),index=np.arange(1,19),columns=['Ratings'])
rate
# Out:
#      Ratings
# 1      PG-13
# 2      TV-MA
# 3         PG
# 4      TV-14
# 5      TV-PG
# 6       TV-Y
# 7      TV-Y7
# 8          R
# 9       TV-G
# 10         G
# 11     NC-17
# 12    74 min
# 13    84 min
# 14    66 min
# 15        NR
# 16       NaN
# 17  TV-Y7-FV
# 18        UR

# %% [markdown]
# ### 10

# %%
data.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...

# %%
data[data['rating'].isnull()]='Null'
df5 = data[data['rating'].apply(lambda x:True if 'TV-14' in x else False)]
print(f"Number of movies rated TV-14 in Canada :{df5[df5['type']=='Movie'][df5[df5['type']=='Movie']['country']=='Canada']['country'].count()}")
# Out:
# Number of movies rated TV-14 in Canada :10

# %% [markdown]
# ### 11

# %%
data['release_year'] = pd.to_numeric(data['release_year'],errors='coerce',downcast='integer')

# %%
df6 = data[data['release_year']>2018]
df7 = df6[df6['rating'].apply(lambda x:True if 'TV-14' in x else False)]['type']
df7
# Out:
# 8       TV Show
# 18        Movie
# 25      TV Show
# 30        Movie
# 68        Movie
#          ...
# 7408    TV Show
# 7478      Movie
# 8079      Movie
# 8468      Movie
# 8752      Movie
# Name: type, Length: 498, dtype: object
