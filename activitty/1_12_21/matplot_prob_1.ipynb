# %%
import matplotlib.pyplot as plt

# %%
prgm_lang = ['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']

# %%
pop = [22.2, 17.6, 8.8, 8, 7.7, 6.7]
colors = ['r','y','b','m','g','c']

# %%
plt.pie(pop,labels=prgm_lang,colors=colors,rotatelabels=True,autopct='%0.2f%%');
