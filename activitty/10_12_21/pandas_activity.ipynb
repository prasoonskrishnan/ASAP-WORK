# %% [markdown]
# # ACTIVITY

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('C:\\Users\\admin\\Documents\\document\\data science\\covid.csv')

# %%
data.set_index('date',inplace=True)

# %%
data.drop('state',axis=1,inplace=True)

# %%
data[(data['cases']>1000) & (data['deaths']>100)]
# Out:
#           cases  deaths
# date
# 15.04.20   1349     107
# 22.04.20   1729     109
# 23.04.20   1961     123
# 13.05.20   2068     112
# 15.05.20   2068     153
# ...         ...     ...
# 26.12.20  64987     257
# 28.12.20  41720     246
# 29.12.20  34166     425
# 30.12.20  32386     437
# 31.12.20  32264     574
#
# [93 rows x 2 columns]

# %%
data
# Out:
#           cases  deaths
# date
# 25.01.20      1       0
# 26.01.20      1       0
# 27.01.20      0       0
# 28.01.20      0       0
# 29.01.20      0       0
# ...         ...     ...
# 27.12.20  37555      62
# 28.12.20  41720     246
# 29.12.20  34166     425
# 30.12.20  32386     437
# 31.12.20  32264     574
#
# [342 rows x 2 columns]

# %%
data['deaths/case'] = data.deaths/data.cases

# %%
# data.fillna(value=0,inplace=True)

# %%
data.applymap(lambda x: '%.4f'%x)
# Out:
#                cases    deaths deaths/case
# date
# 25.01.20      1.0000    0.0000      0.0000
# 26.01.20      1.0000    0.0000      0.0000
# 27.01.20      0.0000    0.0000         nan
# 28.01.20      0.0000    0.0000         nan
# 29.01.20      0.0000    0.0000         nan
# ...              ...       ...         ...
# 27.12.20  37555.0000   62.0000      0.0017
# 28.12.20  41720.0000  246.0000      0.0059
# 29.12.20  34166.0000  425.0000      0.0124
# 30.12.20  32386.0000  437.0000      0.0135
# 31.12.20  32264.0000  574.0000      0.0178
#
# [342 rows x 3 columns]

# %% [markdown]
# ## ACTIVITY TILL HERE

# %%
data.reset_index(inplace=True)

# %%
data['Month'] = pd.to_datetime(data['date'],format='%d.%m.%y').dt.month_name()

# %%
data.set_index('date',inplace=True)

# %%
data
# Out:
#           cases  deaths  deaths/case     Month
# date
# 25.01.20      1       0     0.000000   January
# 26.01.20      1       0     0.000000   January
# 27.01.20      0       0          NaN   January
# 28.01.20      0       0          NaN   January
# 29.01.20      0       0          NaN   January
# ...         ...     ...          ...       ...
# 27.12.20  37555      62     0.001651  December
# 28.12.20  41720     246     0.005896  December
# 29.12.20  34166     425     0.012439  December
# 30.12.20  32386     437     0.013493  December
# 31.12.20  32264     574     0.017791  December
#
# [342 rows x 4 columns]

# %%
data.describe()
# Out:
#               cases      deaths  deaths/case
# count    342.000000  342.000000   317.000000
# mean    6747.862573   75.921053     0.019664
# std    10023.201267   76.639861     0.018158
# min        0.000000   -5.000000    -0.001666
# 25%     1352.250000   22.000000     0.006715
# 50%     3462.500000   62.500000     0.015053
# 75%     7637.250000  104.000000     0.027773
# max    64987.000000  574.000000     0.142857

# %%
data['Month'].value_counts()
# Out:
# March        31
# May          31
# July         31
# August       31
# October      31
# December     31
# April        30
# June         30
# September    30
# November     30
# February     29
# January       7
# Name: Month, dtype: int64

# %%
data2 = data.groupby('Month')['cases'].sum()

# %%
data2
# Out:
# Month
# April          41887
# August        210268
# December     1070577
# February          25
# January            3
# July          270120
# June          119039
# March           8555
# May            62644
# November      301944
# October       114123
# September     108584
# Name: cases, dtype: int64

# %%
data.reset_index(inplace=True)

# %%
data
# Out:
#          date  cases  deaths  deaths/case     Month
# 0    25.01.20      1       0     0.000000   January
# 1    26.01.20      1       0     0.000000   January
# 2    27.01.20      0       0          NaN   January
# 3    28.01.20      0       0          NaN   January
# 4    29.01.20      0       0          NaN   January
# ..        ...    ...     ...          ...       ...
# 337  27.12.20  37555      62     0.001651  December
# 338  28.12.20  41720     246     0.005896  December
# 339  29.12.20  34166     425     0.012439  December
# 340  30.12.20  32386     437     0.013493  December
# 341  31.12.20  32264     574     0.017791  December
#
# [342 rows x 5 columns]

# %%
data1=data['deaths/case'].max()

# %%
data[data['deaths/case']==data1]
# Out:
#         date  cases  deaths  deaths/case  Month
# 45  10.03.20      7       1     0.142857  March

# %%
data
# Out:
#          date  cases  deaths  deaths/case     Month
# 0    25.01.20      1       0     0.000000   January
# 1    26.01.20      1       0     0.000000   January
# 2    27.01.20      0       0          NaN   January
# 3    28.01.20      0       0          NaN   January
# 4    29.01.20      0       0          NaN   January
# ..        ...    ...     ...          ...       ...
# 337  27.12.20  37555      62     0.001651  December
# 338  28.12.20  41720     246     0.005896  December
# 339  29.12.20  34166     425     0.012439  December
# 340  30.12.20  32386     437     0.013493  December
# 341  31.12.20  32264     574     0.017791  December
#
# [342 rows x 5 columns]

# %%
data.dropna(axis=0,how='all')
# Out:
#          date  cases  deaths  deaths/case     Month
# 0    25.01.20      1       0     0.000000   January
# 1    26.01.20      1       0     0.000000   January
# 2    27.01.20      0       0          NaN   January
# 3    28.01.20      0       0          NaN   January
# 4    29.01.20      0       0          NaN   January
# ..        ...    ...     ...          ...       ...
# 337  27.12.20  37555      62     0.001651  December
# 338  28.12.20  41720     246     0.005896  December
# 339  29.12.20  34166     425     0.012439  December
# 340  30.12.20  32386     437     0.013493  December
# 341  31.12.20  32264     574     0.017791  December
#
# [342 rows x 5 columns]

# %%
d = pd.DataFrame(np.random.randint(1,50,12).reshape(4,3))

# %%
d
# Out:
#     0   1   2
# 0  44  45  22
# 1  35  21   3
# 2  14  12  21
# 3  37   5  27

# %%
d.iloc[1:3,2] = np.nan

# %%
d.iloc[0:3,0] = np.nan

# %%
d.iloc[3,0:2] = np.nan

# %%
d
# Out:
#     0     1     2
# 0 NaN  45.0  22.0
# 1 NaN  21.0   NaN
# 2 NaN  12.0   NaN
# 3 NaN   NaN  27.0

# %%
d.dropna(thresh=1,axis=1)
# Out:
#       1     2
# 0  45.0  22.0
# 1  21.0   NaN
# 2  12.0   NaN
# 3   NaN  27.0

# %%
data = dict(A=[1,2,3],B=[4,5,6])

# %%
df1 = pd.DataFrame(data,index=list('abc'))

# %%
data1 = dict(A=[100,200,300],B=[400,500,600])

# %%
df2 = pd.DataFrame(data1,index=list('abc'))

# %%
df1['key1'] = ['k1','k2','k3']
df2['key2'] = ['k4','k5','k6']

# %%
df1
# Out:
#    A  B key1
# a  1  4   k1
# b  2  5   k2
# c  3  6   k3

# %%
df2
# Out:
#      A    B key2
# a  100  400   k4
# b  200  500   k5
# c  300  600   k6

# %%
pd.concat([df1,df2],axis=0)
# Out:
#      A    B key1 key2
# a    1    4   k1  NaN
# b    2    5   k2  NaN
# c    3    6   k3  NaN
# a  100  400  NaN   k4
# b  200  500  NaN   k5
# c  300  600  NaN   k6

# %%
pd.merge(df1,df2,how='outer',on=['A','B'])
# Out:
#      A    B key1 key2
# 0    1    4   k1  NaN
# 1    2    5   k2  NaN
# 2    3    6   k3  NaN
# 3  100  400  NaN   k4
# 4  200  500  NaN   k5
# 5  300  600  NaN   k6

# %%
import pandas as pd
import numpy as np

# %%
data = dict(A=[12,23,34,45,12],B=['python','C++','python','C++','C'],C=['a','b','a','b',np.nan])

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#     A       B    C
# 0  12  python    a
# 1  23     C++    b
# 2  34  python    a
# 3  45     C++    b
# 4  12       C  NaN

# %%
df['A'].unique()
# Out:
# array([12, 23, 34, 45], dtype=int64)

# %%
df['A'].nunique()
# Out:
# 4

# %%
df['A'].apply(lambda x: x*2)
# Out:
# 0    24
# 1    46
# 2    68
# 3    90
# 4    24
# Name: A, dtype: int64

# %%
def coun(x):
    if len(x)<5:
        return x

# %%
df['B'].apply(coun)
# Out:
# 0    None
# 1     C++
# 2    None
# 3     C++
# 4       C
# Name: B, dtype: object

# %%
df['B'].isna()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: B, dtype: bool

# %%
df
# Out:
#     A       B    C
# 0  12  python    a
# 1  23     C++    b
# 2  34  python    a
# 3  45     C++    b
# 4  12       C  NaN

# %%
df.sort_values(['B'],ignore_index=True,inplace=True,ascending=False)

# %%
df
# Out:
#     A       B    C
# 0  34  python    a
# 1  12  python    a
# 2  45     C++    b
# 3  23     C++    b
# 4  12       C  NaN

# %%
d_1 = {'A':['foo','foo','foo','bar','bar','bar'],
     'B':['one','one','two','two','one','one'],
       'C':['x','y','x','y','x','y'],
       'D':[1,3,2,5,4,1]}

df1 = pd.DataFrame(d_1)

# %%
df1
# Out:
#      A    B  C  D
# 0  foo  one  x  1
# 1  foo  one  y  3
# 2  foo  two  x  2
# 3  bar  two  y  5
# 4  bar  one  x  4
# 5  bar  one  y  1

# %%
df1.pivot_table(values='D',index=['A','B'],columns='C')
# Out:
# C          x    y
# A   B
# bar one  4.0  1.0
#     two  NaN  5.0
# foo one  1.0  3.0
#     two  2.0  NaN
